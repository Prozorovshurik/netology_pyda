# %% [markdown]
# # Домашнее задание
# 1. Переведите содержимое файла purchase_log.txt в словарь purchases вида:
# ```python
# {'1840e0b9d4': 'Продукты', ...}
# ```
#
# 2. Для каждого user_id в файле visit_log.csv добавьте третий столбец с категорией покупки (если покупка была).
#
# 3. Запишите в файл funnel.csv визиты из файла visit_log.csv, в которых были покупки с указанием категории.
#
# Учтите условия на данные:
# - содержимое purchase_log.txt помещается в оперативную память компьютера
# - содержимое visit_log.csv - нет; используйте только построчную обработку этого файла

# %% [markdown]
# Описание алгоритма для себя:
# 1. открыть файл purchase_log.txt, прочитать, удалить /n строки, пробелы, скобки
# извлечь срез по индексам превратить  строку в формат: id , category
# разделить на список по запятой ,
# добавить в словарь по индексу списка
# записать словарь в файл purchases.txt
# 2. Открыть файл visit_log.cvc читать, построчно, разделяя строки на списки по символу ","
# далее подставляя элемент списка с индексом [0] в функцию .get как ключ, ищем наличие значения в файле со словарём,
# если находим то методом .append добавляем в строку в и записываем строку в funnel.cvc, если не находим то ничего не делаем

# %%
import json
diction = {}
i=0
print(diction)
with open ( 'purchase_log.txt', 'r', encoding='utf-8') as origin:
    for data in origin.readlines():
        #data = origin.readline()
        #print(data)#Control-line

        data = data.strip()
        #data = data.replace(' ','')
        data = json.loads(data)
        #print (type(data))
        temp_list = []
        #data = data.split(',')
        for v in data.values():
            #temp_list = []
            temp_list.append(v)
            #print('temp', temp_list)
            #print('in cycle', diction)
        diction[temp_list[0]] = temp_list[1]
    #print( type(diction))
    #data = data.split(',')
diction_to_str = str(diction)
with open ('pur.txt', 'w') as nf:
    nf.write(str(diction_to_str))
    #nf.write(json.dumps(diction))
print(type(diction))
# Out:
# {}
# <class 'dict'>

# %%
#2.
import json
with open ('visit_log.csv', 'r') as visits:
    #i = 0
    for line in visits:
        visits.readline()
        line = line.strip().split(',')
        if line[0] in diction.keys():
            true_value  = diction.get(line[0],'')
            line.append(true_value)
            with open ('funnel.csv', 'a') as funnel:
                line = str(line)
                funnel.write(line)
                #funnel.write(json.dumps(line))
                funnel.close()
            print(line)
        else:
            print(line)
# Out:
# ['user_id', 'source', 'category']
# ['b4ea53e670', 'other']
# ['96064ae9e0', 'other']
# ['71bcf169b4', 'other']
# ['1f8845e157', 'context']
# ['dd85040770', 'other']
# ['86835b81ac', 'context']
# ['1b75c4f23f', 'other']
# ['f697206af5', 'other']
# ['dd3d43c266', 'context']
# ['b18d58560b', 'email']
# ['1840e0b9d4', 'other', 'Продукты']
# ['470248aabf', 'other']
# ['03592d16ac', 'other']
# ['ceda3a4603', 'other']
# ['6074c89112', 'context']
# ['cb9dd569e7', 'context']
# ['c0075c117c', 'other']
# ['cddb2fc63e', 'other']
# ['f1708b0dba', 'other']
# ['3b8889be65', 'other']
# ['9e7e01d962', 'email']
# ['892de9fb9c', 'context']
# ['36e5386eab', 'other']
# ['bf9d1ad797', 'other']
# ['423bb91bd9', 'context']
# ['e977795a7e', 'other']
# ['4111731cef', 'context']
# ['983bd13cab', 'other']
# ['2abbac2d31', 'other']
# ['d09edf5601', 'context']
# ['23ebe451aa', 'context']
# ['4ef5b2f5df', 'other']
# ['14c73d53c1', 'context']
# ['563649baca', 'context']
# ['ae35a7ee31', 'other']
# ...
