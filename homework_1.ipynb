# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
print (len(long_phrase)>len(short_phrase))
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах. Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*"

# %%
byte_size= int(input("Введите размер файла в байтах "))/1024

if byte_size<=0 or byte_size==False:#не работает цикл проверки на не корректный ввод дробного,отрицательного числа или текста не вижу ошибку
    print("Вы ввели некорректное значение")
print('"Объём файла равен',byte_size,'Mb."')
# Out:
# Введите размер файла в байтах 876
# "Объём файла равен 0.85546875 Mb."

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
month = str(input("Введите месяц рождения "))
day = int(input("введите число дня рождения "))

if month == "январь":
    if 21>day>0:
        print ("Ваш знак Козерог")
    elif 21<=day<=31:
        print ("Вы Водолей")
    else: print ("Введите корректное число месяца")
elif month == "февраль":
    if 20>day>0:
        print ("Ваш знак Водолей")
    elif 20<=day<=28:
        print ("Вы Рыбы")
    elif day== 29:
        print("ВЫ СЧАСЛИВЧИК!!!")
    else: print ("Введите корректное число месяца")
        
elif month == "март":
    if 21>day>0:
        print ("Ваш знак Рыбы")
    elif 21<=day<=31:
        print ("Вы Овен")
    else: print ("Введите корректное число месяца")
        
elif month == "апрель":
    if 21>day>0:
        print ("Ваш знак Овен")
    elif 21<=day<=30:
        print ("Вы Телец")
    else: print ("Введите корректное число месяца")
        
elif month == "май":
    if 22>day>0:
        print ("Ваш знак Телец")
    elif 22<=day<=31:
        print ("Вы Близнец")
    else: print ("Введите корректное число месяца")
        
elif month == "июнь":
    if 22>day>0:
        print ("Ваш знак Близнец")
    elif 22<=day<=30:
        print ("Вы Рак")
    else: print ("Введите корректное число месяца")
        
elif month == "июль":
    if 22>day>0:
        print ("Ваш знак Рак")
    elif 23<=day<=31:
        print ("Вы ЛЕВ")
    else: print ("Введите корректное число месяца")
        
elif month == "август":
    if 24>day>0:
        print ("Ваш знак ЛЕВ")
    elif 24<=day<=31:
        print ("Вы Дева")
    else: print ("Введите корректное число месяца")
        
elif month == "сентябрь":
    if 23>day>0:
        print ("Ваш знак Дева")
    elif 23<=day<=30:
        print ("Вы Весы")
    else: print ("Введите корректное число месяца")
        
elif month == "октябрь":
    if 23>day>0:
        print ("Ваш знак Весы")
    elif 23<=day<=31:
        print ("Вы Скорпион")
    else: print ("Введите корректное число месяца")
        
elif month == "ноябрь":
    if 23>day>0:
        print ("Ваш знак Скорпион")
    elif 23<=day<=30:
        print ("Вы Стрелец")
    else: print ("Введите корректное число месяца")
        
elif month == "декабрь":
    if 22>day>0:
        print ("Ваш знак Стрелец")
    elif 22<=day<=31:
        print ("Вы Козерог??")
    else: print ("Введите корректное число месяца")       
    
else:
    print ("Введите корректное наименование месяца")
#Думаю слишком много циклов for, нужно подумать как оптимизировать.
# Out:
# Введите месяц рождения январь
# введите число дня рождения 1
# Ваш знак Козерог

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
zp=int(input("Введите вашу заработную плату в месяц. "))
if zp<=0:
    print ("Некорректная сумма заработной платы") #Необходима проверка на ввод текста
part_ipoteka= int(input("Сколько процентов заработной платы вы тратите на оплату ипотеки? "))
if part_ipoteka<0:
    print ("Некорректный процент платежа по ипотеке") #Необходима проверка на ввод текста
part_life= int(input("Сколько процентов заработной платы вы тратите на жизнь? "))
if part_life<0:
    print ("Некорректный процент трат на жизнь") #Необходима проверка на ввод текста
    
count_award= int(input("Сколько раз год вы получаете премию? "))
if count_award<0:
    print("Некорректный ввод количества премий")#Необходима проверка на ввод текста 
    
pens_sum= zp-(zp/100*part_ipoteka)-(zp/100*part_life)

vac_sum= count_award*zp*0.5 #расчёт суммы отложенной на отпуск
vac_pens_sum= (count_award*zp)-vac_sum

print("На ипотеку было потрачено ", zp/100*part_ipoteka*12,"рублей." )#изменить формат вывода, целое
print("Было накоплено ", pens_sum*12+vac_pens_sum,"рублей.")

#print("Сумма на пенсию, отпуск, доп", pens_sum, vac_sum, vac_pens_sum) #строка для проверки, закоментировать перед финалом
# Out:
# Введите вашу заработную плату в месяц. 0
# Некорректная сумма заработной платы
# Сколько процентов заработной платы вы тратите на оплату ипотеки? 0
# Сколько процентов заработной платы вы тратите на жизнь? 0
# Сколько раз год вы получаете премию? 0
# На ипотеку было потрачено  0.0 рублей.
# Было накоплено  0.0 рублей.
